# %%
import pandas as pd
df = pd.read_csv('result.csv')

# %%
df
# Out:
#    micro_accuracy  macro_accuracy  micro_auc  macro_auc  micro_precision  \
# 0         0.00000         0.00000    0.00000    0.00000          0.00000
# 1         0.50902         0.41517    0.92979    0.90082          0.76572
# 2         0.46815         0.39452    0.92233    0.89734          0.72023
#
#    macro_precision  micro_recall  macro_recall  micro_f1  macro_f1   ...     \
# 0          0.00000       0.00000       0.00000   0.00000   0.00000   ...
# 1          0.66522       0.60292       0.50710   0.67463   0.57550   ...
# 2          0.61973       0.57221       0.49419   0.63774   0.54989   ...
#
#    macro_P@1  micro_P@5  macro_P@5  micro_P@8  macro_P@8  micro_P@10  \
# 0    0.00000        0.0    0.00000        0.0    0.00000         0.0
# 1    0.86524        0.0    0.64986        0.0    0.52545         0.0
# 2    0.83054        0.0    0.62256        0.0    0.50904         0.0
#
#    macro_P@10  micro_P@15  macro_P@15    level
# 0     0.00000         0.0     0.00000        0
# ...
